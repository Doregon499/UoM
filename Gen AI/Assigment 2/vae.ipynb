# %% [markdown]
# # Variational AutoEncoder
#
# **Author:** [fchollet](https://twitter.com/fchollet)<br>
# **Date created:** 2020/05/03<br>
# **Last modified:** 2024/04/24<br>
# **Description:** Convolutional Variational AutoEncoder (VAE) trained on MNIST digits.

# %% [markdown]
# ## Setup

# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"

import numpy as np
import tensorflow as tf
import keras
from keras import ops
from keras import layers

# %% [markdown]
# ## Create a sampling layer

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.seed_generator = keras.random.SeedGenerator(1337)

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = ops.shape(z_mean)[0]
        dim = ops.shape(z_mean)[1]
        epsilon = keras.random.normal(shape=(batch, dim), seed=self.seed_generator)
        return z_mean + ops.exp(0.5 * z_log_var) * epsilon

# %% [markdown]
# ## Build the encoder

# %%
latent_dim = 2

encoder_inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(32, 3, activation="relu", strides=2, padding="same")(encoder_inputs)
x = layers.Conv2D(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Flatten()(x)
x = layers.Dense(16, activation="relu")(x)
z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 28, 28, 1)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 14, 14, 32)     │            320 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 7, 7, 64)       │         18,496 │ conv2d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten (Flatten)         │ (None, 3136)           │              0 │ conv2d_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 16)             │         50,192 │ flatten[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ z_mean (Dense)            │ (None, 2)              │             34 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ z_log_var (Dense)         │ (None, 2)              │             34 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ sampling (Sampling)       │ (None, 2)              │              0 │ z_mean[0][0],          │
# │                           │                        │                │ z_log_var[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 69,076 (269.83 KB)
#  Trainable params: 69,076 (269.83 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Build the decoder

# %%
latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(7 * 7 * 64, activation="relu")(latent_inputs)
x = layers.Reshape((7, 7, 64))(x)
x = layers.Conv2DTranspose(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Conv2DTranspose(32, 3, activation="relu", strides=2, padding="same")(x)
decoder_outputs = layers.Conv2DTranspose(1, 3, activation="sigmoid", padding="same")(x)
decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 2)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3136)                │           9,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape (Reshape)                    │ (None, 7, 7, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose (Conv2DTranspose)   │ (None, 14, 14, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_1 (Conv2DTranspose) │ (None, 28, 28, 32)          │          18,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_2 (Conv2DTranspose) │ (None, 28, 28, 1)           │             289 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 65,089 (254.25 KB)
#  Trainable params: 65,089 (254.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Define the VAE as a `Model` with a custom `train_step`

# %%
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = ops.mean(
                ops.sum(
                    keras.losses.binary_crossentropy(data, reconstruction),
                    axis=(1, 2),
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - ops.square(z_mean) - ops.exp(z_log_var))
            kl_loss = ops.mean(ops.sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

# %% [markdown]
# ## Train the VAE

# %%
(x_train, _), (x_test, _) = keras.datasets.mnist.load_data()
mnist_digits = np.concatenate([x_train, x_test], axis=0)
mnist_digits = np.expand_dims(mnist_digits, -1).astype("float32") / 255

vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam())
vae.fit(mnist_digits, epochs=30, batch_size=128)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 16s 12ms/step - kl_loss: 1.8625 - loss: 258.6948 - reconstruction_loss: 256.8323
# Epoch 2/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 4.0666 - loss: 184.7928 - reconstruction_loss: 180.7263
# Epoch 3/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - kl_loss: 5.9486 - loss: 167.2361 - reconstruction_loss: 161.2875
# Epoch 4/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.2622 - loss: 162.8531 - reconstruction_loss: 156.5911
# Epoch 5/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.4104 - loss: 159.7436 - reconstruction_loss: 153.3332
# Epoch 6/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - kl_loss: 6.4453 - loss: 158.9409 - reconstruction_loss: 152.4956
# Epoch 7/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - kl_loss: 6.4372 - loss: 157.4646 - reconstruction_loss: 151.0274
# Epoch 8/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.4527 - loss: 156.5925 - reconstruction_loss: 150.1398
# Epoch 9/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.4368 - loss: 156.1077 - reconstruction_loss: 149.6709
# Epoch 10/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.4183 - loss: 155.5977 - reconstruction_loss: 149.1794
# Epoch 11/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - kl_loss: 6.4208 - loss: 154.5917 - reconstruction_loss: 148.1709
# Epoch 12/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.4536 - loss: 154.4434 - reconstruction_loss: 147.9897
# Epoch 13/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - kl_loss: 6.4346 - loss: 153.3869 - reconstruction_loss: 146.9522
# Epoch 14/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.4608 - loss: 152.8500 - reconstruction_loss: 146.3891
# Epoch 15/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - kl_loss: 6.4489 - loss: 153.3691 - reconstruction_loss: 146.9202
# Epoch 16/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.4340 - loss: 152.7091 - reconstruction_loss: 146.2751
# Epoch 17/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.4405 - loss: 152.6324 - reconstruction_loss: 146.1919
# Epoch 18/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - kl_loss: 6.4486 - loss: 152.0101 - reconstruction_loss: 145.5614
# Epoch 19/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - kl_loss: 6.4360 - loss: 152.0354 - reconstruction_loss: 145.5995
# Epoch 20/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.4180 - loss: 151.8824 - reconstruction_loss: 145.4643
# Epoch 21/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - kl_loss: 6.4056 - loss: 151.4290 - reconstruction_loss: 145.0233
# Epoch 22/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.4543 - loss: 150.6140 - reconstruction_loss: 144.1596
# Epoch 23/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - kl_loss: 6.4299 - loss: 151.1435 - reconstruction_loss: 144.7136
# Epoch 24/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.4368 - loss: 150.8143 - reconstruction_loss: 144.3774
# Epoch 25/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - kl_loss: 6.4348 - loss: 151.0765 - reconstruction_loss: 144.6417
# Epoch 26/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - kl_loss: 6.4218 - loss: 150.3474 - reconstruction_loss: 143.9256
# Epoch 27/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.4201 - loss: 150.5371 - reconstruction_loss: 144.1169
# Epoch 28/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.4340 - loss: 150.1908 - reconstruction_loss: 143.7568
# Epoch 29/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.4277 - loss: 150.1331 - reconstruction_loss: 143.7054
# Epoch 30/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - kl_loss: 6.4480 - loss: 150.1568 - reconstruction_loss: 143.7088

# %% [markdown]
# ## Display a grid of sampled digits

# %%
import matplotlib.pyplot as plt


def plot_latent_space(vae, n=30, figsize=15):
    # display a n*n 2D manifold of digits
    digit_size = 28
    scale = 1.0
    figure = np.zeros((digit_size * n, digit_size * n))
    # linearly spaced coordinates corresponding to the 2D plot
    # of digit classes in the latent space
    grid_x = np.linspace(-scale, scale, n)
    grid_y = np.linspace(-scale, scale, n)[::-1]

    for i, yi in enumerate(grid_y):
        for j, xi in enumerate(grid_x):
            z_sample = np.array([[xi, yi]])
            x_decoded = vae.decoder.predict(z_sample, verbose=0)
            digit = x_decoded[0].reshape(digit_size, digit_size)
            figure[
                i * digit_size : (i + 1) * digit_size,
                j * digit_size : (j + 1) * digit_size,
            ] = digit

    plt.figure(figsize=(figsize, figsize))
    start_range = digit_size // 2
    end_range = n * digit_size + start_range
    pixel_range = np.arange(start_range, end_range, digit_size)
    sample_range_x = np.round(grid_x, 1)
    sample_range_y = np.round(grid_y, 1)
    plt.xticks(pixel_range, sample_range_x)
    plt.yticks(pixel_range, sample_range_y)
    plt.xlabel("z[0]")
    plt.ylabel("z[1]")
    plt.imshow(figure, cmap="Greys_r")
    plt.show()


plot_latent_space(vae)

# %% [markdown]
# ## Display how the latent space clusters different digit classes

# %%
def plot_label_clusters(vae, data, labels):
    # display a 2D plot of the digit classes in the latent space
    z_mean, _, _ = vae.encoder.predict(data, verbose=0)
    plt.figure(figsize=(12, 10))
    plt.scatter(z_mean[:, 0], z_mean[:, 1], c=labels)
    plt.colorbar()
    plt.xlabel("z[0]")
    plt.ylabel("z[1]")
    plt.show()


(x_train, y_train), _ = keras.datasets.mnist.load_data()
x_train = np.expand_dims(x_train, -1).astype("float32") / 255

plot_label_clusters(vae, x_train, y_train)

# %% [markdown]
# Extra exteps to use the VAE as generator

# %%
def generate_single_image(decoder):
    random_latent_vector = np.random.normal(size=(1, latent_dim))
    generated_image = decoder.predict(random_latent_vector)
    plt.imshow(generated_image[0].reshape(28, 28), cmap="gray")
    plt.axis("off")
    plt.show()

generate_single_image(decoder)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %% [markdown]
# Gen n=10 img

# %%
def generate_images(decoder, n):
    plt.figure(figsize=(20, 4))
    for i in range(n):
        random_latent_vector = np.random.normal(size=(1, latent_dim))
        generated_image = decoder.predict(random_latent_vector)
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(generated_image[0].reshape(28, 28), cmap="gray")
        plt.axis("off")
    plt.show()

generate_images(decoder, 10)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %%
"""
## Build the encoder
"""

latent_dim = 3

encoder_inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(32, 3, activation="relu", strides=2, padding="same")(encoder_inputs)
x = layers.Conv2D(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Flatten()(x)
x = layers.Dense(16, activation="relu")(x)
z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()

"""
## Build the decoder
"""

latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(7 * 7 * 64, activation="relu")(latent_inputs)
x = layers.Reshape((7, 7, 64))(x)
x = layers.Conv2DTranspose(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Conv2DTranspose(32, 3, activation="relu", strides=2, padding="same")(x)
decoder_outputs = layers.Conv2DTranspose(1, 3, activation="sigmoid", padding="same")(x)
decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()
# Out:
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2             │ (None, 28, 28, 1)      │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 14, 14, 32)     │            320 │ input_layer_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 7, 7, 64)       │         18,496 │ conv2d_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_1 (Flatten)       │ (None, 3136)           │              0 │ conv2d_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 16)             │         50,192 │ flatten_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ z_mean (Dense)            │ (None, 3)              │             51 │ dense_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ z_log_var (Dense)         │ (None, 3)              │             51 │ dense_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ sampling_1 (Sampling)     │ (None, 3)              │              0 │ z_mean[0][0],          │
# │                           │                        │                │ z_log_var[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 69,110 (269.96 KB)
#  Trainable params: 69,110 (269.96 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)           │ (None, 3)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 3136)                │          12,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape_1 (Reshape)                  │ (None, 7, 7, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_3 (Conv2DTranspose) │ (None, 14, 14, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_4 (Conv2DTranspose) │ (None, 28, 28, 32)          │          18,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_5 (Conv2DTranspose) │ (None, 28, 28, 1)           │             289 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 68,225 (266.50 KB)
#  Trainable params: 68,225 (266.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
(x_train, _), (x_test, _) = keras.datasets.mnist.load_data()
mnist_digits = np.concatenate([x_train, x_test], axis=0)
mnist_digits = np.expand_dims(mnist_digits, -1).astype("float32") / 255

vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam())
vae.fit(mnist_digits, epochs=30, batch_size=128)
# Out:
# Epoch 1/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - kl_loss: 3.0251 - loss: 255.5137 - reconstruction_loss: 252.4885
# Epoch 2/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 5.8864 - loss: 179.2440 - reconstruction_loss: 173.3576
# Epoch 3/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - kl_loss: 6.0171 - loss: 167.2579 - reconstruction_loss: 161.2409
# Epoch 4/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.2703 - loss: 163.0420 - reconstruction_loss: 156.7717
# Epoch 5/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.3723 - loss: 160.7307 - reconstruction_loss: 154.3584
# Epoch 6/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.3917 - loss: 158.6751 - reconstruction_loss: 152.2834
# Epoch 7/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.4414 - loss: 157.2208 - reconstruction_loss: 150.7794
# Epoch 8/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.4724 - loss: 156.4803 - reconstruction_loss: 150.0079
# Epoch 9/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - kl_loss: 6.4963 - loss: 155.4122 - reconstruction_loss: 148.9158
# Epoch 10/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - kl_loss: 6.5278 - loss: 154.4706 - reconstruction_loss: 147.9428
# Epoch 11/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - kl_loss: 6.5046 - loss: 154.2749 - reconstruction_loss: 147.7704
# Epoch 12/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - kl_loss: 6.5373 - loss: 153.8477 - reconstruction_loss: 147.3104
# Epoch 13/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - kl_loss: 6.5021 - loss: 153.3426 - reconstruction_loss: 146.8405
# Epoch 14/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.5112 - loss: 152.5155 - reconstruction_loss: 146.0043
# Epoch 15/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - kl_loss: 6.5087 - loss: 152.8460 - reconstruction_loss: 146.3373
# Epoch 16/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.5148 - loss: 152.1834 - reconstruction_loss: 145.6686
# Epoch 17/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - kl_loss: 6.5208 - loss: 152.2806 - reconstruction_loss: 145.7599
# Epoch 18/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.5393 - loss: 152.0502 - reconstruction_loss: 145.5109
# Epoch 19/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - kl_loss: 6.5330 - loss: 151.7075 - reconstruction_loss: 145.1745
# Epoch 20/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - kl_loss: 6.5224 - loss: 151.0382 - reconstruction_loss: 144.5158
# Epoch 21/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.5125 - loss: 150.8134 - reconstruction_loss: 144.3008
# Epoch 22/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - kl_loss: 6.5055 - loss: 150.6513 - reconstruction_loss: 144.1458
# Epoch 23/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - kl_loss: 6.5259 - loss: 150.6415 - reconstruction_loss: 144.1155
# Epoch 24/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.5238 - loss: 150.1696 - reconstruction_loss: 143.6458
# Epoch 25/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.5215 - loss: 150.1328 - reconstruction_loss: 143.6112
# Epoch 26/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - kl_loss: 6.5439 - loss: 150.1395 - reconstruction_loss: 143.5956
# Epoch 27/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - kl_loss: 6.5220 - loss: 149.8688 - reconstruction_loss: 143.3468
# Epoch 28/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.5492 - loss: 149.3951 - reconstruction_loss: 142.8458
# Epoch 29/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - kl_loss: 6.5471 - loss: 149.8499 - reconstruction_loss: 143.3028
# Epoch 30/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - kl_loss: 6.5378 - loss: 149.5350 - reconstruction_loss: 142.9971

# %%
import matplotlib.pyplot as plt

def plot_latent_slices(vae, n=10, figsize=15):
    digit_size = 28
    scale = 1.0

    slice_indices = [
        (0, 1),  # z[0] vs z[1]
        (0, 2),  # z[0] vs z[2]
        (1, 2)   # z[1] vs z[2]
    ]

    for idx, (i, j) in enumerate(slice_indices):
        figure = np.zeros((digit_size * n, digit_size * n))
        grid_x = np.linspace(-scale, scale, n)
        grid_y = np.linspace(-scale, scale, n)[::-1]

        for m, yi in enumerate(grid_y):
            for l, xi in enumerate(grid_x):
                z_sample = np.zeros((1, latent_dim))
                z_sample[0, i] = xi
                z_sample[0, j] = yi
                x_decoded = vae.decoder.predict(z_sample, verbose=0)
                digit = x_decoded[0].reshape(digit_size, digit_size)
                figure[
                    m * digit_size : (m + 1) * digit_size,
                    l * digit_size : (l + 1) * digit_size,
                ] = digit

        plt.figure(figsize=(figsize, figsize))
        start_range = digit_size // 2
        end_range = n * digit_size + start_range
        pixel_range = np.arange(start_range, end_range, digit_size)
        sample_range_x = np.round(grid_x, 1)
        sample_range_y = np.round(grid_y, 1)
        plt.xticks(pixel_range, sample_range_x)
        plt.yticks(pixel_range, sample_range_y)
        plt.xlabel(f"z[{i}]")
        plt.ylabel(f"z[{j}]")
        plt.imshow(figure, cmap="Greys_r")
        plt.show()

plot_latent_slices(vae)

# %%
def generate_images(decoder, n):
    plt.figure(figsize=(20, 4))
    for i in range(n):
        random_latent_vector = np.random.normal(size=(1, latent_dim))
        generated_image = decoder.predict(random_latent_vector)
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(generated_image[0].reshape(28, 28), cmap="gray")
        plt.axis("off")
    plt.show()

generate_images(decoder, 10)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %% [markdown]
# interpolation

# %%
"""
## Build the encoder
"""

latent_dim = 2

encoder_inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(32, 3, activation="relu", strides=2, padding="same")(encoder_inputs)
x = layers.Conv2D(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Flatten()(x)
x = layers.Dense(16, activation="relu")(x)
z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()

"""
## Build the decoder
"""

latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(7 * 7 * 64, activation="relu")(latent_inputs)
x = layers.Reshape((7, 7, 64))(x)
x = layers.Conv2DTranspose(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Conv2DTranspose(32, 3, activation="relu", strides=2, padding="same")(x)
decoder_outputs = layers.Conv2DTranspose(1, 3, activation="sigmoid", padding="same")(x)
decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()

(x_train, _), (x_test, _) = keras.datasets.mnist.load_data()
mnist_digits = np.concatenate([x_train, x_test], axis=0)
mnist_digits = np.expand_dims(mnist_digits, -1).astype("float32") / 255

vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam())
vae.fit(mnist_digits, epochs=30, batch_size=128)
# Out:
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4             │ (None, 28, 28, 1)      │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 14, 14, 32)     │            320 │ input_layer_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 7, 7, 64)       │         18,496 │ conv2d_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_2 (Flatten)       │ (None, 3136)           │              0 │ conv2d_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 16)             │         50,192 │ flatten_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ z_mean (Dense)            │ (None, 2)              │             34 │ dense_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ z_log_var (Dense)         │ (None, 2)              │             34 │ dense_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ sampling_2 (Sampling)     │ (None, 2)              │              0 │ z_mean[0][0],          │
# │                           │                        │                │ z_log_var[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 69,076 (269.83 KB)
#  Trainable params: 69,076 (269.83 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)           │ (None, 2)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 3136)                │           9,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape_2 (Reshape)                  │ (None, 7, 7, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_6 (Conv2DTranspose) │ (None, 14, 14, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_7 (Conv2DTranspose) │ (None, 28, 28, 32)          │          18,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_8 (Conv2DTranspose) │ (None, 28, 28, 1)           │             289 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 65,089 (254.25 KB)
#  Trainable params: 65,089 (254.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - kl_loss: 2.2876 - loss: 254.1608 - reconstruction_loss: 251.8732
# Epoch 2/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - kl_loss: 3.4384 - loss: 187.4639 - reconstruction_loss: 184.0255
# Epoch 3/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - kl_loss: 5.6937 - loss: 169.4892 - reconstruction_loss: 163.7956
# Epoch 4/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - kl_loss: 6.0841 - loss: 164.9351 - reconstruction_loss: 158.8510
# Epoch 5/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - kl_loss: 6.3066 - loss: 161.4756 - reconstruction_loss: 155.1690
# Epoch 6/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.4239 - loss: 160.1397 - reconstruction_loss: 153.7159
# Epoch 7/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.4612 - loss: 158.7139 - reconstruction_loss: 152.2526
# Epoch 8/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.4626 - loss: 157.6365 - reconstruction_loss: 151.1740
# Epoch 9/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - kl_loss: 6.4775 - loss: 157.2936 - reconstruction_loss: 150.8161
# Epoch 10/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.4470 - loss: 156.4864 - reconstruction_loss: 150.0394
# Epoch 11/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.4377 - loss: 155.8344 - reconstruction_loss: 149.3966
# Epoch 12/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - kl_loss: 6.4238 - loss: 155.2872 - reconstruction_loss: 148.8635
# Epoch 13/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - kl_loss: 6.4008 - loss: 154.9869 - reconstruction_loss: 148.5861
# Epoch 14/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - kl_loss: 6.4040 - loss: 154.5076 - reconstruction_loss: 148.1036
# Epoch 15/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - kl_loss: 6.3940 - loss: 154.0290 - reconstruction_loss: 147.6350
# Epoch 16/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - kl_loss: 6.3706 - loss: 153.8553 - reconstruction_loss: 147.4847
# Epoch 17/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - kl_loss: 6.3448 - loss: 153.6885 - reconstruction_loss: 147.3437
# Epoch 18/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - kl_loss: 6.3431 - loss: 153.2065 - reconstruction_loss: 146.8634
# Epoch 19/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.3557 - loss: 152.9856 - reconstruction_loss: 146.6299
# Epoch 20/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - kl_loss: 6.3633 - loss: 152.5470 - reconstruction_loss: 146.1837
# Epoch 21/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.3471 - loss: 152.3752 - reconstruction_loss: 146.0281
# Epoch 22/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.3572 - loss: 151.9007 - reconstruction_loss: 145.5435
# Epoch 23/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - kl_loss: 6.3390 - loss: 152.0634 - reconstruction_loss: 145.7244
# Epoch 24/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - kl_loss: 6.3730 - loss: 151.6288 - reconstruction_loss: 145.2558
# Epoch 25/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - kl_loss: 6.3699 - loss: 151.1067 - reconstruction_loss: 144.7368
# Epoch 26/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.3622 - loss: 151.4226 - reconstruction_loss: 145.0604
# Epoch 27/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - kl_loss: 6.3443 - loss: 151.4675 - reconstruction_loss: 145.1232
# Epoch 28/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - kl_loss: 6.3904 - loss: 150.8578 - reconstruction_loss: 144.4674
# Epoch 29/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - kl_loss: 6.3874 - loss: 150.8152 - reconstruction_loss: 144.4278
# Epoch 30/30
# 547/547 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - kl_loss: 6.4017 - loss: 150.7023 - reconstruction_loss: 144.3005

# %%
import matplotlib.pyplot as plt

def interpolate_points(p1, p2, n_steps=20):
    ratios = np.linspace(0, 1, num=n_steps)
    vectors = []
    for ratio in ratios:
        vector = p1 * (1 - ratio) + p2 * ratio
        vectors.append(vector)
    return np.array(vectors)

def plot_latent_interpolation(vae, data, n=20):
    # Select two random latent space points
    z1 = np.random.normal(size=(1, latent_dim))
    z2 = np.random.normal(size=(1, latent_dim))

    # Interpolate between the two latent points
    z_interp = interpolate_points(z1, z2, n)

    # Reshape z_interp to (n, latent_dim) before prediction
    z_interp = z_interp.reshape(n, latent_dim)

    # Generate images from the interpolated latent points
    interpolated_images = vae.decoder.predict(z_interp)

    # Plot the interpolated images
    plt.figure(figsize=(20, 4))
    for i in range(n):
        ax = plt.subplot(1, n, i + 1)
        plt.imshow(interpolated_images[i].reshape(28, 28), cmap="gray")
        plt.axis("off")
    plt.show()

plot_latent_interpolation(vae, mnist_digits)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
